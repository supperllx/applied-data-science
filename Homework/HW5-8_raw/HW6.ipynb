# %% [markdown]
# # CPSC6300-001 Applied Data Science - HW6¶

# %% [markdown]
# # Part B. Visually Exploring the Data (50 points)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %% [markdown]
# ## 1. Histograms of Attributes
#
# Finish the following code to plot a histograms of the numerical attributes of the housing data using 50 bins. Set the figure size to  $20×15$  and the layout to  $3×3$ .

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpt
import seaborn as sns

housing = pd.read_csv("datasets/housing.csv")

# %%
sns.set(color_codes=True)
sns.set(style="white", palette="muted")

### BEGIN SOLUTION

### END SOLUTION

# %% [markdown]
# ## 2. Capped Attributes
#
# List the set of attributes whose values capped along with their lower and upper caps. Present your answer as a dict type, e.g.:
# ```
# {
#     "attribut_a": [10, 1000],
#     "attribute_b": [5, 600]
# }
# ```

# %%
### BEGIN SOLUTION

### END SOLUTION
capped_attributes
# Out:
# {'median_house_value': [14999.0, 500001.0],
#  'housing_median_age': [1.0, 52.0],
#  'median_income': [0.4999, 15.0001]}

# %% [markdown]
# ## 3. Transformed Attribute Values
#
# The values of median_income do not seem to match the actual income distribution in the United States. How do you explan this discrepancy? Write your answer into a block string variable __explain__.

# %%
### BEGIN SOLUTION
explain ="""
"""
### END SOLUTION
print(explain)

# %% [markdown]
# ## 4. Long Tail Distribution
#
# List at least two attributes whose histograms are tail heavy: they extend much farther to the right than to the left. Save your list into a variable __long_tail_attributes__.

# %%
### BEGIN SOLUTION

### END SOLUTION
for a in sorted(long_tail_attributes):
    print(a)
# Out:
# Household
# median_income
# population
# total_bedrooms
# total_rooms

# %% [markdown]
# ## 5. Distribution Plots
#
# Using the distplot() method in the seaborn library to plot the distributions of normalized histograms for median income and normalized mean housing value in a single figure similar to the one shown below (you don't need to make your figure exactly same as this figure).
# <img src="distplot.png">

# %%
### BEGIN SOLUTION

### END SOLUTION
# Out:
# Text(0.5, 0, 'normalized median income and housing value')

# %% [markdown]
# ## 6. Scatter Matrix
#
# Scatter matrix is a good visualization to check correlations between attributes. Use the seaborn's pairplot() method to plot the scatter matrix of housing data. Before you start, consider the following three hints:
#
# 1. pairplot only applies to numerical attributes.
# 2. pairplot cannot directly handle the NaN value.
# 3. When the dataset is large, the plotting may be slow.
#
# You may preprocess the data going into the pairplot() method by dropping certain columns and rows. Also, since you only want to see an overall trend, it may be efficient to plot a fraction of the datasets.

# %%
### BEGIN SOLUTION

### END SOLUTION

# %% [markdown]
# ## 7. Correlation Matrix vs Scatter Matrix
#
# a. Compuet the correlation coefficients between each pair of the numerical attributes and save the results to a variable __corr_matrix__.

# %%
### BEGIN SOLUTION

### END SOLUTION
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %% [markdown]
# b. Print the top three attributes that have the strongest correlation with median_house_value and the corresponding correlation coefficients.

# %%
### BEGIN SOLUTION

### END SOLUTION
# Out:
# median_income 0.6880752079585525
# total_rooms 0.13415311380656475
# housing_median_age 0.10562341249321036

# %% [markdown]
# c. Plot the scatter plot between __median_income__ and __median_house_value__ into a figure of size $10 \times 8$. Use __ocean_proximity__ as __hue__.

# %%
### BEGIN SOLUTION

### END SOLUTION

# %% [markdown]
# ## 8. Visualize Geographical Data (10 points)
#
# When a dataset contains geographical information (latitude and longitude), creating a geographical scatterplot of the data can reveal very useful information.

# %% [markdown]
# a. Create a scatterplot using the __(latitude, longitude)__ as the cordinates, 1/50 of the population as the size of the marker, and the median house value as the color. You can use the "jet" colormap.

# %%
### BEGIN SOLUTION

### END SOLUTION

# %% [markdown]
# b. You can overlay the scatterplot on top of a map of the region. One simplest way to achieve this overlay is to load an map image and then show the image on the same axes which contains the scatterplot. You can pass an argument "zorder=0" to axes.imshow() and "zorder=1" to the scattplot method you have used.
#
# You can use the image "ca.png" for the ca map. To read and show an image, you can use the following method:
# ```
# img = mpt.image.imread("ca.png")
# plt.imshow(img, extent=bounded_box)
# ```

# %%
bounded_box = (housing.longitude.min(), housing.longitude.max(), housing.latitude.min(), housing.latitude.max())
### BEGIN SOLUTION

### END SOLUTION

# %% [markdown]
# __End of Part B__.
